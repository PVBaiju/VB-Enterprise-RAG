# %%
# ==========================================================
# NOTEBOOK 05_query_test.py
# ==========================================================

# %pip install google-generativeai faiss-cpu

import google.generativeai as genai
import pandas as pd
import numpy as np
import faiss

genai.configure(api_key="AIzaSyBrc4jMrz4w5mO2sRwNO854YQEjuuRLOE0")

index = faiss.read_index("/dbfs/FileStore/faiss/docs.index")
meta = pd.read_pickle("/dbfs/FileStore/faiss/metadata.pkl")

question = "What is annual leave?"

q = genai.embed_content(
    model="models/gemini-embedding-2",
    content=question,
    task_type="RETRIEVAL_QUERY"
)["embedding"]

q = np.array([q]).astype("float32")

D, I = index.search(q, 3)

context = ""

for idx in I[0]:
    context += meta.iloc[idx]["chunk_text"] + "\n\n"

prompt = f"""
Use only context.

Context:
{context}

Question:
{question}
"""

res = genai.GenerativeModel(
"gemini-2.0-flash"
).generate_content(prompt)

print(res.text)
# Out:
# ...
#   Using cached google_generativeai-0.8.6-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# ...
#   Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached google_api_python_client-2.194.0-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached google_auth_httplib2-0.3.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# ...
# Using cached google_generativeai-0.8.6-py3-none-any.whl (155 kB)
# Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
# Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
# Using cached google_api_python_client-2.194.0-py3-none-any.whl (15.0 MB)
# Using cached google_auth_httplib2-0.3.1-py3-none-any.whl (9.5 kB)
# Using cached uritemplate-4.2.0-py3-none-any.whl (11 kB)
# ...
